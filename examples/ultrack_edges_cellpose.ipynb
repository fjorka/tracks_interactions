# %%
import os

from pathlib import Path

import napari
import numpy as np
from tqdm import tqdm
from rich.pretty import pprint


from ultrack import track, to_tracks_layer, tracks_to_zarr
from ultrack.imgproc import normalize
from ultrack.utils import estimate_parameters_from_labels, labels_to_edges
from ultrack.utils.array import array_apply, create_zarr
from ultrack.config import MainConfig
from ultrack.core.solve.processing import solve
from ultrack.imgproc.segmentation import reconstruction_by_dilation, Cellpose
from ultrack.utils.cuda import import_module, to_cpu, torch_default_device

import dask.array as da

import matplotlib.pyplot as plt

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# frames_start = 115
# frames_stop = 125
# row_start = 4250
# row_stop = 4750
# col_start = 4200
# col_stop = 4900

frames_start = 0
frames_stop = -1
row_start = 0
row_stop = -1
col_start = 0
col_stop = -1

# %%
#ch0_path = r'D:\kasia\tracking\E6_exp\E6_C0.zarr'
ch1_path = r'D:\kasia\tracking\E6_exp\E6_C1.zarr'

#ch0_da = da.from_zarr(ch0_path,1)[frames_start:frames_stop, row_start:row_stop, col_start:col_stop]
ch1_da = da.from_zarr(ch1_path,1)[frames_start:frames_stop, row_start:row_stop, col_start:col_stop]

#print(ch0_da.shape)
print(ch1_da.shape)
# Out:
# (240, 8395, 8400)
# (240, 8395, 8400)

# %% [markdown]
# ### Normalize and create zarr

# %%
chunks = (1, 512, 512)

ch1_normalized_path = r'D:\kasia\tracking\E6_exp\E6_C1_normalized.zarr'

# %%
normalized = create_zarr(ch1_da.shape, np.float16, ch1_normalized_path, chunks=chunks, overwrite=True)
array_apply(
    ch1_da,
    out_array=normalized,
    func=normalize,
    gamma=0.5,
)
# Out:
# Applying normalize ...:   0%|          | 0/240 [00:00<?, ?it/s]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   0%|          | 1/240 [00:06<26:30,  6.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   1%|          | 2/240 [00:13<27:05,  6.83s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   1%|▏         | 3/240 [00:20<26:40,  6.75s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   2%|▏         | 4/240 [00:27<26:41,  6.79s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   2%|▏         | 5/240 [00:33<26:34,  6.79s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   2%|▎         | 6/240 [00:40<26:12,  6.72s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   3%|▎         | 7/240 [00:47<26:43,  6.88s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   3%|▎         | 8/240 [00:54<26:44,  6.92s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   4%|▍         | 9/240 [01:01<27:03,  7.03s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   4%|▍         | 10/240 [01:08<26:10,  6.83s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   5%|▍         | 11/240 [01:18<30:25,  7.97s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   5%|▌         | 12/240 [01:25<29:08,  7.67s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   5%|▌         | 13/240 [01:32<28:22,  7.50s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   6%|▌         | 14/240 [01:39<27:32,  7.31s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   6%|▋         | 15/240 [01:46<26:58,  7.19s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   7%|▋         | 16/240 [01:53<26:38,  7.13s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   7%|▋         | 17/240 [02:00<26:21,  7.09s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   8%|▊         | 18/240 [02:07<25:54,  7.00s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   8%|▊         | 19/240 [02:14<25:40,  6.97s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   8%|▊         | 20/240 [02:21<25:31,  6.96s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   9%|▉         | 21/240 [02:32<29:41,  8.14s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:   9%|▉         | 22/240 [02:39<28:16,  7.78s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  10%|▉         | 23/240 [02:45<27:01,  7.47s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  10%|█         | 24/240 [02:52<25:54,  7.19s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  10%|█         | 25/240 [02:59<25:32,  7.13s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  11%|█         | 26/240 [03:06<25:01,  7.02s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  11%|█▏        | 27/240 [03:13<24:53,  7.01s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  12%|█▏        | 28/240 [03:20<24:47,  7.02s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  12%|█▏        | 29/240 [03:27<24:50,  7.06s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  12%|█▎        | 30/240 [03:34<24:27,  6.99s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  13%|█▎        | 31/240 [03:45<28:19,  8.13s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  13%|█▎        | 32/240 [03:51<26:31,  7.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  14%|█▍        | 33/240 [03:58<25:22,  7.35s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  14%|█▍        | 34/240 [04:04<24:35,  7.16s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  15%|█▍        | 35/240 [04:11<24:07,  7.06s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  15%|█▌        | 36/240 [04:18<23:36,  6.95s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  15%|█▌        | 37/240 [04:25<23:18,  6.89s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  16%|█▌        | 38/240 [04:31<23:03,  6.85s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  16%|█▋        | 39/240 [04:38<22:38,  6.76s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  17%|█▋        | 40/240 [04:45<22:22,  6.71s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  17%|█▋        | 41/240 [04:51<22:01,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  18%|█▊        | 42/240 [04:58<21:53,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  18%|█▊        | 43/240 [05:05<22:07,  6.74s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  18%|█▊        | 44/240 [05:11<21:41,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  19%|█▉        | 45/240 [05:18<21:46,  6.70s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  19%|█▉        | 46/240 [05:25<21:33,  6.67s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  20%|█▉        | 47/240 [05:31<21:19,  6.63s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  20%|██        | 48/240 [05:38<21:04,  6.59s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  20%|██        | 49/240 [05:44<21:01,  6.61s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  21%|██        | 50/240 [05:51<20:56,  6.61s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  21%|██▏       | 51/240 [05:58<21:04,  6.69s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  22%|██▏       | 52/240 [06:05<21:06,  6.74s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  22%|██▏       | 53/240 [06:11<20:44,  6.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  22%|██▎       | 54/240 [06:18<20:36,  6.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  23%|██▎       | 55/240 [06:24<20:20,  6.60s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  23%|██▎       | 56/240 [06:31<20:24,  6.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  24%|██▍       | 57/240 [06:38<20:16,  6.65s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  24%|██▍       | 58/240 [06:44<20:03,  6.61s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  25%|██▍       | 59/240 [06:51<20:01,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  25%|██▌       | 60/240 [06:57<19:47,  6.60s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  25%|██▌       | 61/240 [07:04<19:47,  6.63s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  26%|██▌       | 62/240 [07:11<19:35,  6.60s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  26%|██▋       | 63/240 [07:17<19:34,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  27%|██▋       | 64/240 [07:24<19:38,  6.69s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  27%|██▋       | 65/240 [07:31<19:28,  6.68s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  28%|██▊       | 66/240 [07:37<19:13,  6.63s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# ...
#   warnings.warn(
# Applying normalize ...:  91%|█████████ | 218/240 [25:13<02:29,  6.77s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  91%|█████████▏| 219/240 [25:20<02:22,  6.78s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  92%|█████████▏| 220/240 [25:26<02:13,  6.70s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  92%|█████████▏| 221/240 [25:37<02:32,  8.01s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  92%|█████████▎| 222/240 [25:44<02:15,  7.55s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  93%|█████████▎| 223/240 [25:50<02:02,  7.23s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  93%|█████████▎| 224/240 [25:57<01:52,  7.02s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  94%|█████████▍| 225/240 [26:03<01:42,  6.85s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  94%|█████████▍| 226/240 [26:10<01:34,  6.75s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  95%|█████████▍| 227/240 [26:16<01:26,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  95%|█████████▌| 228/240 [26:23<01:19,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  95%|█████████▌| 229/240 [26:30<01:13,  6.68s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  96%|█████████▌| 230/240 [26:36<01:06,  6.70s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  96%|█████████▋| 231/240 [26:47<01:12,  8.03s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  97%|█████████▋| 232/240 [26:54<01:00,  7.56s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  97%|█████████▋| 233/240 [27:00<00:50,  7.25s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  98%|█████████▊| 234/240 [27:07<00:42,  7.02s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  98%|█████████▊| 235/240 [27:13<00:34,  6.90s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  98%|█████████▊| 236/240 [27:20<00:27,  6.75s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  99%|█████████▉| 237/240 [27:26<00:19,  6.64s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...:  99%|█████████▉| 238/240 [27:33<00:13,  6.61s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...: 100%|█████████▉| 239/240 [27:39<00:06,  6.56s/it]c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\dask\array\core.py:1712: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# Applying normalize ...: 100%|██████████| 240/240 [27:46<00:00,  6.94s/it]

# %% [markdown]
# ### Cellpose segmentation

# %%
# run if reading in
normalized = da.from_zarr(ch1_normalized_path)

# %%
ch1_labels_segm_path = r'D:\kasia\tracking\E6_exp\E6_C1_labels_normalized.zarr'

cellpose_labels = create_zarr(normalized.shape, np.uint16, ch1_labels_segm_path, chunks=chunks, overwrite=True)

array_apply(
    normalized,
    out_array=cellpose_labels,
    func=Cellpose(model_type="cyto2", device=torch_default_device()),
    tile=True,
    normalize=False,
    diameter = 50,
)
# Out:
# Applying Cellpose ...:  39%|███▉      | 94/240 [54:44<1:25:00, 34.94s/it]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 5
#       1 ch1_labels_segm_path = r'D:\kasia\tracking\E6_exp\E6_C1_labels_normalized.zarr'
#       3 cellpose_labels = create_zarr(normalized.shape, np.uint16, ch1_labels_segm_path, chunks=chunks, overwrite=True)
# ----> 5 array_apply(
#       6     normalized,
#       7     out_array=cellpose_labels,
#       8     func=Cellpose(model_type="cyto2", device=torch_default_device()),
#       9     tile=True,
#      10     normalize=False,
#      11     diameter = 50,
#      12 )
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\ultrack\utils\array.py:138, in array_apply(out_array, func, axis, *in_arrays, **kwargs)
#     136     stub_slicing[a] = i
#     137 indexing = tuple(stub_slicing)
# --> 138 out_array[indexing] = func(*[a[indexing] for a in in_arrays], **kwargs)
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\ultrack\imgproc\segmentation.py:226, in Cellpose.__call__(self, image, **kwargs)
#     221 def __call__(self, image: ArrayLike, **kwargs) -> np.ndarray:
#     222     """
#     223     Predicts image labels.
#     224     See cellpose.models.Cellpose.eval documentation for details.
#     225     """
# --> 226     labels, _, _, _ = self.model.eval(image, **kwargs)
#     227     return labels
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\models.py:188, in Cellpose.eval(self, x, batch_size, channels, channel_axis, invert, normalize, diameter, do_3D, **kwargs)
#     186 tic = time.time()
#     187 models_logger.info("~~~ FINDING MASKS ~~~")
# --> 188 masks, flows, styles = self.cp.eval(x, channels=channels,
#     189                                     channel_axis=channel_axis,
#     190                                     batch_size=batch_size, normalize=normalize,
#     191                                     invert=invert, diameter=diams, do_3D=do_3D,
#     192                                     **kwargs)
#     194 models_logger.info(">>>> TOTAL TIME %0.2f sec" % (time.time() - tic0))
#     196 return masks, flows, styles, diams
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\models.py:410, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, stitch_threshold, min_size, niter, augment, tile, tile_overlap, bsize, interp, compute_masks, progress)
#     407     diameter = self.diam_labels
#     408     rescale = self.diam_mean / diameter
# --> 410 masks, styles, dP, cellprob, p = self._run_cp(
#     411     x, compute_masks=compute_masks, normalize=normalize, invert=invert,
#     412     rescale=rescale, resample=resample, augment=augment, tile=tile,
#     413     tile_overlap=tile_overlap, bsize=bsize, flow_threshold=flow_threshold,
#     414     cellprob_threshold=cellprob_threshold, interp=interp, min_size=min_size,
#     415     do_3D=do_3D, anisotropy=anisotropy, niter=niter,
#     416     stitch_threshold=stitch_threshold)
#     418 flows = [plot.dx_to_circ(dP), dP, cellprob, p]
#     419 return masks, flows, styles
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\models.py:517, in CellposeModel._run_cp(self, x, compute_masks, normalize, invert, niter, rescale, resample, augment, tile, tile_overlap, cellprob_threshold, bsize, flow_threshold, min_size, interp, anisotropy, do_3D, stitch_threshold)
#     514 iterator = trange(nimg, file=tqdm_out,
#     515                   mininterval=30) if nimg > 1 else range(nimg)
#     516 for i in iterator:
# --> 517     outputs = dynamics.resize_and_compute_masks(
#     518         dP[:, i],
#     519         cellprob[i],
#     520         niter=niter,
#     521         cellprob_threshold=cellprob_threshold,
#     522         flow_threshold=flow_threshold,
#     523         interp=interp,
#     524         resize=resize,
#     525         min_size=min_size if stitch_threshold == 0 or nimg == 1 else
#     526         -1,  # turn off for 3D stitching
#     527         device=self.device if self.gpu else None)
#     528     masks.append(outputs[0])
#     529     p.append(outputs[1])
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:779, in resize_and_compute_masks(dP, cellprob, p, niter, cellprob_threshold, flow_threshold, interp, do_3D, min_size, resize, device)
#     758 def resize_and_compute_masks(dP, cellprob, p=None, niter=200, cellprob_threshold=0.0,
#     759                              flow_threshold=0.4, interp=True, do_3D=False, min_size=15,
#     760                              resize=None, device=None):
#     761     """Compute masks using dynamics from dP and cellprob, and resizes masks if resize is not None.
#     762
#     763     Args:
#    (...)
#     777         tuple: A tuple containing the computed masks and the final pixel locations.
#     778     """
# --> 779     mask, p = compute_masks(dP, cellprob, p=p, niter=niter,
#     780                             cellprob_threshold=cellprob_threshold,
#     781                             flow_threshold=flow_threshold, interp=interp, do_3D=do_3D,
#     782                             min_size=min_size, device=device)
#     784     if resize is not None:
#     785         mask = transforms.resize_image(mask, resize[0], resize[1],
#     786                                        interpolation=cv2.INTER_NEAREST)
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:836, in compute_masks(dP, cellprob, p, niter, cellprob_threshold, flow_threshold, interp, do_3D, min_size, device)
#     833 if not do_3D:
#     834     if mask.max() > 0 and flow_threshold is not None and flow_threshold > 0:
#     835         # make sure labels are unique at output of get_masks
# --> 836         mask = remove_bad_flow_masks(mask, dP, threshold=flow_threshold,
#     837                                      device=device)
#     839 if mask.max() > 2**16 - 1:
#     840     recast = True
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:657, in remove_bad_flow_masks(masks, flows, threshold, device)
#     654         dynamics_logger.info("turn off QC step with flow_threshold=0 if too slow")
#     655         device0 = None
# --> 657 merrors, _ = metrics.flow_error(masks, flows, device0)
#     658 badi = 1 + (merrors > threshold).nonzero()[0]
#     659 masks[np.isin(masks, badi)] = 0
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\metrics.py:256, in flow_error(maski, dP_net, device)
#     253     return
#     255 # flows predicted from estimated masks
# --> 256 dP_masks = dynamics.masks_to_flows(maski, device=device)
#     257 # difference between predicted flows vs mask flows
#     258 flow_errors = np.zeros(maski.max())
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:358, in masks_to_flows(masks, device, niter)
#     356     return mu
#     357 elif masks.ndim == 2:
# --> 358     mu, mu_c = masks_to_flows_device(masks, device=device, niter=niter)
#     359     return mu
#     361 else:
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:182, in masks_to_flows_gpu(masks, device, niter)
#     180 n_iter = 2 * ext.max() if niter is None else niter
#     181 shape = masks_padded.shape
# --> 182 mu = _extend_centers_gpu(neighbors, meds_p, isneighbor, shape, n_iter=n_iter,
#     183                          device=device)
#     185 # new normalization
#     186 mu /= (1e-60 + (mu**2).sum(axis=0)**0.5)
#
# File c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\cellpose\dynamics.py:80, in _extend_centers_gpu(neighbors, meds, isneighbor, shape, n_iter, device)
#      78 for i in range(n_iter):
#      79     T[meds[:, 0], meds[:, 1]] += 1
# ---> 80     Tneigh = T[tuple(neighbors)]
#      81     Tneigh *= isneighbor
#      82     T[tuple(neighbors[:, 0])] = Tneigh.mean(axis=0)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 768.00 MiB. GPU 0 has a total capacity of 8.00 GiB of which 0 bytes is free. Of the allocated memory 5.83 GiB is allocated by PyTorch, and 1.04 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# view labels
viewer = napari.Viewer()
viewer.add_imag(ch1_da, name="ch1",visible=False)
viewer.add_image(normalized, name="normalized", visible=False)
viewer.add_labels(cellpose_labels, name="cellpose_labels", visible=False)

# %%
zarr_masks_path2 = r'D:\kasia\tracking\E6_exp\code\tracks_interactions\examples\240311_cellpose_labels.zarr'

dask_masks2 = da.from_zarr(zarr_masks_path2)
dask_masks2.shape
# Out:
# (10, 500, 700)

# %%
detection2, edges2 = labels_to_edges(dask_masks2, 
                                   detection_store_or_path="detection2.zarr", 
                                   edges_store_or_path="edges2.zarr", 
                                   overwrite=True, 
                                   sigma=4.0)
# Out:
# Converting labels to edges:   0%|          | 0/10 [00:00<?, ?it/s]
# Converting labels to edges: 100%|██████████| 10/10 [00:00<00:00, 36.17it/s]

# %%
config = MainConfig()
config.segmentation_config.min_area = 400
config.segmentation_config.max_area = 2000
config.segmentation_config.min_frontier = 0.1
config.segmentation_config.n_workers = 10

config.linking_config.max_distance = 25
config.linking_config.n_workers = 10

config.tracking_config.appear_weight = -1
config.tracking_config.disappear_weight = -1
config.tracking_config.division_weight = -0.1
config.tracking_config.power = 4
config.tracking_config.bias = -0.001
config.tracking_config.solution_gap = 0.0

config.tracking_config.window_size = 50
config.tracking_config.overlap_size = 5

pprint(config)
# Out:
# MainConfig(
# │   data_config=DataConfig(working_dir=WindowsPath('.'), database='sqlite', address=None, n_workers=1),
# │   segmentation_config=SegmentationConfig(
# │   │   threshold=0.5,
# │   │   min_area=400,
# │   │   max_area=2000,
# │   │   min_frontier=0.1,
# │   │   anisotropy_penalization=0.0,
# │   │   max_noise=0.0,
# │   │   ws_hierarchy=<function watershed_hierarchy_by_area at 0x000001ED4294AD40>,
# │   │   n_workers=10
# │   ),
# │   linking_config=LinkingConfig(
# │   │   n_workers=10,
# │   │   max_neighbors=5,
# │   │   max_distance=25,
# │   │   distance_weight=0.0,
# │   │   z_score_threshold=5.0
# │   ),
# │   tracking_config=TrackingConfig(
# │   │   appear_weight=-1,
# │   │   disappear_weight=-1,
# │   │   division_weight=-0.1,
# │   │   dismiss_weight_guess=None,
# │   │   include_weight_guess=None,
# │   │   window_size=50,
# │   │   overlap_size=5,
# │   │   solution_gap=0.0,
# │   │   time_limit=36000,
# │   │   method=0,
# │   │   n_threads=-1,
# │   │   link_function='power',
# │   │   power=4,
# │   │   bias=-0.001
# │   )
# )

# %%
detection = da.from_zarr('detection.zarr')#(r"D:\kasia\tracking\E6_exp\code\tests\detection.zarr")
edges = da.from_zarr('edges.zarr')#(r"D:\kasia\tracking\E6_exp\code\tests\edges.zarr")
detection2 = da.from_zarr('detection2.zarr')#(r"D:\kasia\tracking\E6_exp\code\tests\detection.zarr")
edges2 = da.from_zarr('edges2.zarr')#(r"D:\kasia\tracking\E6_exp\code\tests\edges.zarr")

# %%
# tracking directly from the labels
# may require more memory to keep edges in
track(
    labels=dask_masks,
    sigma=4.0,
    config=config,
    overwrite=True, #"solutions" - to recalculate from the database
)

# %%
track(
    labels= [dask_masks, dask_masks2],
    config=config,
    overwrite=True,
)
# Out:
# Converting labels to edges: 100%|██████████| 10/10 [00:00<00:00, 17.06it/s]
# WARNING:ultrack.core.segmentation.processing:Found zarr with MemoryStore. Using an zarr with MemoryStore can lead to considerable memory usage.
# WARNING:ultrack.core.segmentation.processing:Found zarr with MemoryStore. Using an zarr with MemoryStore can lead to considerable memory usage.
# Adding nodes to database: 100%|██████████| 10/10 [00:10<00:00,  1.00s/it]
# Linking nodes.: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Using Gurobi solver
# Solving ILP batch 0
# Constructing ILP ...
# Solving ILP ...
# Saving solution ...
# Done!

# %%
tracks_df, graph = to_tracks_layer(config)
labels = tracks_to_zarr(config, tracks_df)
# Out:
# Exporting segmentation masks:   0%|          | 0/10 [00:00<?, ?it/s]
# Exporting segmentation masks: 100%|██████████| 10/10 [00:00<00:00, 117.65it/s]

# %%
viewer = napari.Viewer()
viewer.add_image(ch0_da, name="ch0", colormap="green", blending="additive")
viewer.add_image(ch1_da, name="ch1", colormap="red", blending="additive")
viewer.add_labels(dask_masks)
viewer.add_image(edges, blending="additive", colormap="magma")
viewer.add_image(edges2, blending="additive", colormap="magma")
viewer.add_labels(labels)
# Out:
# c:\Users\kmk280\.conda\envs\ultrack-env\lib\site-packages\napari\_qt\qt_main_window.py:629: UserWarning: Using NAPARI_PERFMON with an already-running QtApp (--gui qt?) is not supported.
#   qapp = get_app()
# <Labels layer 'labels' at 0x1ed110d9660>

# %%
viewer.add_labels(dask_masks2)
# Out:
# <Labels layer 'dask_masks2' at 0x1ed2ab49ab0>
